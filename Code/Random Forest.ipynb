# %%
import pandas as pd

import numpy as np
np.random.seed(2021)

import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS

import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
#nltk.download('wordnet') #download if not present already

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn import neighbors
from sklearn import datasets
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
#reading in data
tweet_label = pd.read_csv("../Data/vader_sample_label.csv")
tweet_label = tweet_label.drop(["Jakob", "Jamie", "Darren", "Agree w/ Vader", "Heather"], axis=1)
tweet_label
# Out:
#                                                   text  positive  negative  \
# 0    Weve heard that false information about the CO...      0.00      1.00
# 1    Completely agree. Be smart and get the vaccine...      0.64      0.36
# 2    You know whats even crazier than indiscriminat...      0.73      0.27
# 3    Not my problem. Ive not been seeing anyone sin...      0.79      0.21
# 4    If those wanting a vaccine got the vaccine why...      0.70      0.30
# ..                                                 ...       ...       ...
# 995  The David Hookstead Show: 4th Of July Weekend ...      0.00      1.00
# 996  Um. The whole justification was to vaccinate i...      0.63      0.37
# 997  UWM supported by &amp; in collab with #NSS &am...      0.61      0.39
# 998  Ooops.An error: health department says Sydney ...      0.00      1.00
# 999  Its funny/pathetic how colleges are just like ...      1.00      0.00
#
#      assigned Final Decision
# 0    Negative              p
# 1    Positive              p
# 2    Positive              a
# 3    Positive              a
# 4    Positive              a
# ..        ...            ...
# 995  Negative              u
# 996  Positive              u
# 997  Positive              u
# 998  Negative              u
# 999  Positive              a
#
# [1000 rows x 5 columns]

# %%
#replacing labels with numbers
mapping_sentiment = {"Positive": 1, "Negative": 0}
mapping_vaccine = {"p": 1, "a": 0, "u": 2}
tweet_label = tweet_label.replace({"assigned": mapping_sentiment, "Final Decision": mapping_vaccine})

# %%
#dropping 2's (unknowns) and reindexing
tweet_label = tweet_label[tweet_label["Final Decision"] != 2]
tweet_label = tweet_label.reset_index(drop = True)

# %%
#1 if vader assigned label matched manually assigned label
vader_match = [1 if tweet_label["assigned"][i] == tweet_label["Final Decision"][i] else 0 for i in range(len(tweet_label))]

#vader_match = []
#for i in range(len(tweet_label)):
#    if tweet_label["assigned"][i] == tweet_label["Final Decision"][i]:
#        vader_match.append(1)
#    else:
#        vader_match.append(0)
    
tweet_label["vader_match"] = vader_match

# %%
#cleaning functions

def cleaning(text): #to remove mentions and links, taken partially from juejue's and Jamie's notebooks
    text = re.sub(r'[^\w\s]', ' ', text) #remove punctuation
    text = re.sub('\S*@\S*\s?', '',text) #remove emails
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))',' ', text) #remove links
    text = re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", '', text) #also removes links?
    text = re.sub(r'\d+', '', text) #remove numbers
    return text

def clean_stem(tweets, rawtweets = True): #cleaning and stemming
    if rawtweets == True:
        #raw tweets pulled straight from Twitter
        #clears the 'b and the ' at the start and end of the tweet
        tweets = tweets.str[2:] #dropping first two characters apostrophe and b
        tweets = tweets.str[:-1] #dropping last character apostrophe
    
    tweets = tweets.apply(cleaning)

    return tweets

# %%
tweet_label["clean_text"] = clean_stem(tweet_label["text"], rawtweets = False)
tweet_label
# Out:
#                                                   text  positive  negative  \
# 0    Weve heard that false information about the CO...      0.00      1.00
# 1    Completely agree. Be smart and get the vaccine...      0.64      0.36
# 2    You know whats even crazier than indiscriminat...      0.73      0.27
# 3    Not my problem. Ive not been seeing anyone sin...      0.79      0.21
# 4    If those wanting a vaccine got the vaccine why...      0.70      0.30
# ..                                                 ...       ...       ...
# 699  Thank you for passing the amendment protecting...      0.58      0.42
# 700  The data, from Imperial College London, sugges...      0.31      0.69
# 701  Forcing college students to receive Covid vacc...      0.00      1.00
# 702  The funny part is i was supposed to get my vac...      0.20      0.80
# 703  Its funny/pathetic how colleges are just like ...      1.00      0.00
#
#      assigned  Final Decision  vader_match  \
# 0           0               1            0
# 1           1               1            1
# 2           1               0            0
# 3           1               0            0
# 4           1               0            0
# ..        ...             ...          ...
# 699         1               0            0
# 700         0               1            0
# 701         0               0            1
# 702         0               1            0
# 703         1               0            0
#
#                                             clean_text
# 0    Weve heard that false information about the CO...
# 1    Completely agree  Be smart and get the vaccine...
# 2    You know whats even crazier than indiscriminat...
# 3    Not my problem  Ive not been seeing anyone sin...
# 4    If those wanting a vaccine got the vaccine why...
# ..                                                 ...
# 699  Thank you for passing the amendment protecting...
# 700  The data  from Imperial College London  sugges...
# 701  Forcing college students to receive Covid vacc...
# 702  The funny part is i was supposed to get my vac...
# 703  Its funny pathetic how colleges are just like ...
#
# [704 rows x 7 columns]

# %%
stemmer = SnowballStemmer("english")
text = tweet_label["clean_text"].to_list()
process_tweets = []
for sentence in text:
    #iterate through each word in a tweet/sentence, if not part of stopwords list then keep in tweet
    process_tweets.append(" ".join([stemmer.stem(i) for i in sentence.split() if i not in gensim.parsing.preprocessing.STOPWORDS]))

process_tweets
# Out:
# ['weve heard fals inform covid vaccin women hesit get jab the royal colleg midwiv the royal colleg obstetrician gynaecologist evid suggest covidvaccin',
#  'complet agre be smart vaccin your take obnoxi team colleg basebal',
#  'you know what crazier indiscrimin mandat healthi colleg kid covid vaccin do not mandat staff one actual risk make sens',
#  'not problem ive see covid happen i shop colleg area there case im good im healthi i need vaccin',
#  'if want vaccin got vaccin care let peopl worri i bet mask peopl issu i critiqu save kid colleg are eat healthi do text drive do read kid',
#  'nc state fault want play vaccin polit best chanc win colleg world seri team vaccin best shot caus covid boot lol dumb player coach',
#  'i understand jab vaccin experiment canada colleg physician amp politician ban use ivermectin treatment covid peru mexico india provid citizen decim covid seem charg murder',
#  'uhhhhh overheard mom sister get vaccin theyr gonna stop pay colleg haha fuck',
#  'state gop lawmak move block univers requir return student proof covid vaccin vaccin push complic presid joe biden effort shot young adult',
#  'student su indiana univers vaccin mandat constitut right pleas tell constitut say constitut right colleg',
#  'the politic vaccin liter save live mind bend stupid while declin encourag player vaxx nc state coach said want talk polit talk head sport med',
#  'congrat vania of wilmington year old vania won k scholarship state vaccin lotteri draw the high school freshman land summer job help pay colleg happen',
#  'let tri nc colleg student incent prior student or parent student m k vax bonu nc colleg w highest vax rate ncgov nc doctor incentiv counsel medicaid patient covid vax',
#  'except vaccin player appar test posit so vaccin narrat doesnt work',
#  'hs amp colleg athlet got covid year got myocard that way develop vaccin so yes let talk risk assess',
#  'listen folk this cost live mandat proof vaccin enrol colleg new it thing long time vaccin pleas covid vaccin',
#  'ill colleg amp job i hate i live hous bank own i wont vaccin i refus govern tell',
#  'yep they forc colleg vaccin want come school meanwhil cdc employe vaccin that red flag if cdc isnt fulli vaccin i neee complet bullshit',
#  'this studi medic colleg they miss collect data infect rest hcwwhat happen previous infect hcw vaccin prior second wave we resid got infect got vaccin got rtpcr posit',
#  'there upsid give teenag colleg student covid vaccin onli downsid pleas stop children dont use women childbear age pregnant pregnant',
#  'whi whi peopl decid covid vaccin bad shouldnt requir vaccin requir enter regular k school colleg okay these peopl dumb',
#  'those fire methodist colleg is fight after past year life death theyr make vaccin dont need caught covid lawsuit process theyv said suprem court necessari god bless',
#  'realiti set recent myrtl grove middl school grad vania martinez believ won north carolina cash colleg vaccin lotteri',
#  'past subject vaccin passport yellow fever mandatori vaccin hep b amp famili member requir disclos vaccin status prior studi us colleg no problem entir acceptabl',
#  'my son congenit condit i spoke specialist seen born we choos covid vaccin his colleg mandat vaccin this problem',
#  'how colleg student can say no mandatori vaccin',
#  'your awar test posit vaccin right and covid contribut zero death colleg athlet',
#  'kind repli tweet date nd dose covaxin jorhat colleg i took vaccin come certif kind correct',
#  'and ppl esp doc c differ b w acquir covid natur have complic vs complic aris state colleg societi mandat healthi citizen vaccin moral calculus gt gt utilitarian calculus trolleyolog',
#  'dont forget we nd dose pfizer covid vaccin clinic happen today pm pm psja dr daniel king colleg amp univers center san juan',
#  'for thing visit vaccin site thank encourag work get vaccin for shes teach class colleg english professor shes involv effort rais fund anim chariti',
#  'first interest the vast major colleg student gt yo consent vaccin w fb addl parent',
#  'thank you imperi colleg med proud on note encourag conspiraci theorist vaccin yes vaccin build ovari make develop anti vaxxer follicl embryo popul world',
#  'do know requir vaccin colleg if taken colleg cours kid taken vaccin and mean sheep parent congratul',
#  'the polit cultur war vaccin mandat colleg univ gop state disast fall student return low vax rate delta variant domin winter drive peopl indoor',
#  'im favor polici mandat peopl vaccin travel attend colleg becaus evid show vaccin effect protect covid variant et al if choos vaccin caveat emptor',
#  'happi share rajkot homeopath medic colleg associ technic event cell parul univers success organ nation level slogan amp poster competit vaccin reliabl weapon covid successstori tec',
#  'this argument whi colleg athlet requir vaccin it ncaa problem overal problem world',
#  'basic your say order success colleg degre go forc vaccin dont want that discrimin',
#  'mani hospit havent mandatori staff vaccin it crazi havent hard colleg sport team go level enforc but im specul',
#  'if look heart everi young person ani virus infect like flu myocard case myocard m vaccin shot onli total dumbass travel colleg world seri corona virus vaccin shot',
#  'unpopular opinion ive develop year im aggrav gate keep push vaccin hes doctor medic profession colleg drop leav doctor stop bud googl day say surviv rate',
#  'on report vaccin posit th feboxford univers adult rd febimperi colleg st febbmj th febthes adult measuresi',
#  'zero colleg basebal player serious affect covid year vaccin the protocol joke logic team play yesterday',
#  'informedcons exclus dad say life not same year old colleg student who develop myocard after second moderna shot meet vax mandat attend school',
#  'to honbl cm to day dharmapuri covid camp conduct govt art colleg near token i inject covi shield i age year old thank honbl cm send vaccin valga valamudan',
#  'he won colleg scholarship get vaccin there ohiovaxamillion draw left if child age dose vaccin regist chanc win',
#  'hi can tell vaccin provid sheriden colleg clinic is pfizer moderna thank',
#  'question high school colleg athlet lost life china virus lost life experiment vaccin if vaccin work test fan game vaccin',
#  'i dont my son drove home ca colleg ontario may stop walmart way home snack j amp j vaccin wasnt elig canada want normal get vaccin',
#  'your concern drs i speak sound specious wrt experiment product inform consent concur the risk uncertainti arent disclos whilst colleg unconcern mass legal ethic failur',
#  'i complet agre understand mom low immun elig vaccin medic issu the reason i got bc i return colleg campus fall spend class lab i live fam',
#  'back colleg year vaccin thank fulli vax',
#  'it year ive follow singl cdc guidelin havent gotten sick but i want return school i sick mask god know vaccin a colleg choos',
#  'feel bad team that terribl rug pull yall like my suggest come determin year amp there pandem w vaccin avail get everyon vaccin basic',
#  'wake f peopl cant requir ask vaccin status god tell polit view colleg',
#  'liter tb test send proof vaccin colleg covid vaccin controversi peopl selfish fuck pride listen conspiraci theori smooth brain loser',
#  'saw vist vaccin site today watch colleagu colleg pharmaci awesom vaccin work just give inform veri veri power',
#  'the risk myocard covid cancel us colleg athlet vaer show case vaccin how case myocard low risk youth accept greater good consist inform consent',
#  'your correct he worst are you go polit belief colleg applic how tran rule how vaccin proof need work cruis the list tooooooo long hes bad guy removeron',
#  'but yr old son doesnt health issu want vaccin start colleg there inform qualifi',
#  'anoth fir vaccin scam mumbai this time film product hous cheat one colleg borivali come forward if resid came forward group cheat peopl',
#  'accord governor crash draw nevada resid older receiv dose covid vaccin time promot end',
#  'good gov no public univers deni scienc stop student get educ virtu signal',
#  'vaccin save live thank madison madi help word safeti effect shot',
#  'break year old vania martinez cash colleg scholarship winner covid vaccin lotteri she say got vaccin see loss peopl close',
#  'i figur dont need colleg degre smart fall tracker vaccin theori your data track time use gps phone bankcard so smart peopl believ shit antivaxconspiraci',
#  'crush colleg cours daydrop book ziffitvaccin appointmentbuddi read section this lietak ig photo rabbitsfinish rabbitssprint channel',
#  'where blacklivesmatt white supremacist vaccin murder year old child this beauti black american child entir life ahead dead vaccin virus surviv rate age',
#  'the biden administr ice clear plan provid vaccin access detain peopl ice custodi back away promis free colleg univers tuition student famili make',
#  'pleas stop the sbtet diploma stsem exam are held from juli th in ts inter st year student were promot but not we elig vaccin pleas help us student corna colleg famil suffer',
#  'i concern colleg push hard get vaccin if theyr go requir onlin student vaccin admit ill school im take shit',
#  'you right vaccin colleg right reject exam qualif pal use brain wei',
#  'i cousin die covid yesterday amp mfs think finna pressur larg social gather bunch colleg student like dont vaccin dont want wear mask lmfaoooonopeooooooo',
#  'no forc personn these rule if choos vaccin consequ dont colleg',
#  'what complet idiot say fear silli vaccin effect side effect exist there risk reward studi vaccin greater risk young healthi colleg student covid it kid bodi their choic',
#  'covid colleg vaccin challeng',
#  'were make chang support bc immun plan to best support region vaccin need covid test centr vancouv communiti colleg transit fulli vaccin clinic read announc',
#  'bro i vaccin later month i want invit lol miss opportun tri cowork colleg',
#  'shouldnt vaccin covid it take day posit risk exposur real even healthi colleg kid sick they dumb choic free safe vaccin consequ',
#  'all student human studi colleg hep b shot graduat anim care student rabi shot protect it normal add covid vaccin',
#  'neighbor grand girl age rang believ covid vaccin harm egg children colleg grad trumper parent educ never assum trumper act like jan crowd',
#  'absurd when i went colleg i mening vaccin i complaint wasnt global mening pandem time',
#  'year old colleg freshman die from heart problem one month after second dose moderna vaccin children health defensedo not give experiment vaccin children they affect',
#  'should i encourag as percent recipi oxford astrazeneca vaccin dhaka medic colleg carri antibodi coronavirus covid vaccin antibodi dhaka bangladesh',
#  'i believ individu vaccin isnt unlucki this stupid pre vaccin wide avail heart broke team hs colleg pro play play',
#  'scare sinc tom koch retir im unemploy colleg dropout lot time hand come vaccin my mom gotten scare i dont ball',
#  'day rd mesco colleg covid vaccin center mustaidpura swami yadav corporat along with senior aimim leader ward committe member primari unit presid amp activ member visit center',
#  'if t time listen shenanigan summari ontario colleg physician censor peopl mrn vaccin technolog new pfizer bad astrazeneca ok i guess covid treat vitamin d sunlight amp anti parasit drug invermicin',
#  'my colleg announc vaccin mandat am i go maskless not sure i guess number but there chanc',
#  'send son colleg is vaccin risk worth',
#  'if wasnt allow colleg mmr vaccin fire get covid vaccin',
#  'if think vaccin work peopl risk unvaccin whi care healthi colleg kid get',
#  'this bad nobodi vaccin forc you best choic famili i chose vaccin im sick peopl daili basi but colleg basebal player that ridicul',
#  'i agre peopl risk time target vaccin social group like colleg kid interlink social interact',
#  'colleg physician surgeon ontario censor harass intimid threaten physician provid truth inform covid earli treatment vaccin safeti risk children',
#  'you drop colleg wont vaccin simpl problem solv',
#  'a guy colleg fb group claim know lot ppl die experiment vaccin a friend s mom isn t trivial s lot he quot databas add unverifi advers effect got mad i said t prove die',
#  'do know vaccin administ seneca colleg newnham campus tomorrow june thank',
#  'the age group like attend communiti colleg age rang like spread virus make vaccin mandatori',
#  'insaneno reason healthi colleg kid need vaccin ill surviv rate',
#  'i think data inform vaccin colleg educ like abl determin safe effect i think doesnt like nfls posit spout',
#  'theyr colleg kid im call specif ncaa time use common sens there legitim thousand peopl shoulder shoulder old matt tent night test ran cours easili access vaccin',
#  'theyr independ event logic nfl give absolut zero credenc argument dont need vaccin mayb shouldv pay attent colleg stat class smu',
#  'he want if kid vaccin colleg need play',
#  'how tf sit year colleg ball cuz covid vaccin covid dont wanna evvvvvvvveryon know your take fuck dumb ask like i said shut fuck',
#  'thank that use although vaccin plan s colleg student remain fire line',
#  'somehow colleg footbal season complet heart pandem vaccin readili avail includ equival incid determin nation champion explain ncstate',
#  'the vaccin give youj expectedncaa kick nc state out colleg world seri after vaccin player test posit for covid',
#  'the moderna covid vaccin offer atlanta technic colleg alluriam health amp well friday june pm cleveland dennard center regist reserv spot',
#  'also histor black medic school forgotten meharri medic colleg nashvill involv distribut vaccin test i work nissan covid test site vaccin distribut meharri kmart site',
#  'under fuhrer desanti ask vaccin status demand know colleg student polit affili ok deathsanti',
#  'as rutger colleg alumnus i support refus accept mandatori vaccin experiment potenti danger vaccin great job',
#  'colleg student die receiv vaccin whi healthi colleg student vaccin place',
#  'albion colleg offer year free tuition student get covid vaccin',
#  'you dont have chose employ susi darl vaccin requir much like dont have travel togo malaria vaccin mandatori you didnt have colleg mening vax need',
#  'posit incent day gt vaccin win free colleg ny',
#  'my friend daughter go freshman colleg preme her mom get fake vaccin card',
#  'nc state player test posit covid colleg world seri one assum theyv posit symptomat peopl need wake realiz your con make vaccin manufactur wealthiest peopl america',
#  'not mention women ask old i tri vaccin neighbor thought i colleg rent month place',
#  'you realiz school forc athlet vaccin you vaccin play high school colleg sport so i dont understand resist covid vaccin other dont care peopl care polit',
#  'particip covid colleg vaccin challeng we safe commit action get covid vaccin read campus vaccin requir',
#  'dear sir i taken vaccin mega vaccin drive organis citi polic till i regist cowin show vaccin place vaccin sultan ul uloom colleg date june',
#  'mass vaxmillion vaccin lotteri giveaway includ m winner colleg scholarship',
#  'there go th wave covid juli pak there vaccin colleg student go board exam',
#  'governor az sign execut order protect right student have vaccin order attend colleg no shot mask doe worm governor ball',
#  'the vaccin shouldnt matter point colleg athlet shouldnt test damn final',
#  'i like thank sponsor saint john fisher colleg king cuomo opportun beyond bless forc take vaccin',
#  'one shot richer dont leav free money tabl read learn enter draw scholarship the draw friday juli nd dont wait enter',
#  'im sorri u senior hs amp freshman colleg memor import year i imagin have pandem do u think vaccin deliveri improv soon u leav school',
#  'those hesit coronavirus vaccin includ white evangel republican rural american young adult colleg degre maga maga bing bong',
#  'sir vaccin young plz provid vaccin doctor colleg youngster asap data colleg der student just n eye dem nd outsid allow fst',
#  'europ choos dose prior infect us uk continu demand youth low risk covid want colleg work w o coerc unnecessari vaccin risk if dose necessari appeas beast reduc harm',
#  'shit recommend drug vaccin colleg graduat antivaaaaaaaax simpl',
#  'it ridicul colleg age athlet zero satir risk covid the fact vaccin test posit prove test diagnost there way fals posit it joke meant scare ignor',
#  'this guy useless douch you tell hes bought paid time bar soap prison nice polit legaci arizonagetsscrew',
#  'nevada launch vaccin incent lotteri cash prize colleg scholarship',
#  'you know what wild when enter colleg damn shot record proof requir shot like mening a vaccin passport liter shot record the shot record carri littl',
#  'want win million colleg scholarship massvaxmillion giveaway you fulli vaccin elig registr begin juli arent vaccin win make covidma vaccin appoint today',
#  'got mening b vaccin today bc colleg requir hit like covid vaccin pls',
#  'union counti colleg host free vaccin clinic wednesday june th cranford campus the event featur giveaway raffl prize gift card laptop free tuition student',
#  'you wait vaccineand compuls offlin class oppos open colleg',
#  'my son colleg requir vaccin attend person class live campus unbeliev number parent freak id vaccin yo son i boy dumb',
#  'univers california campus requir covid vaccin fall wait fda approv origin plan bbn covid covidvaccin colleg studentscovid',
#  'colleg vaccin mandat play role im worri mandat major invest edu outreach student colleg strength imo push student higher ed if your gonna mandat gotta address barrier',
#  'across eastern oregon vaccin rate arent near high like there vaccin hesit frank wide open space these smaller communiti alway read',
#  'if athlet wont vaccin colleg world seri disast go happeningit sure didnt like vaccin big priorityfor coach elliott avent saidencourag player vaccin wasnt job descript',
#  'my colleg give peopl bookstor credit vaccin no gave cool deal i got vaccin februari especi textbook',
#  'free vaccin drive colleg student arrang basaveshwar engin colleg bagalkot vaccin for all free for all campaign goi fight covid',
#  'alic take pledg help columbia vaccin champion colleg togeth differ togeth protect communiti togeth wecandothi covidcollegechalleng learn',
#  'colleg basebal show vaccin isnt worth everi player wasnt vaccin test negat everi player vaccin test posit make sens i know ive known mannnnnnn',
#  'sign covid colleg vaccin challeng the white hous amp invit colleg univers countri join effort end pandem sign covid colleg vaccin challeng',
#  'i got dose vaccin th may the second dose deadlin end rd june when i abl second dose vaccin center jorhat colleg jorhat age kind let know',
#  'cdc lie what qanon my colleg daughter friend univers got pfizer hospit heart inflamm',
#  'better own repug rule',
#  'if your laport surround area j amp j vaccineno appoint necessari san jancinto colleg maritim center old highway la port oper time am pm share share share',
#  'republican leader arent afraid vaccin hesit popul republican district elector colleg',
#  'advis vaccin seneca colleg newnham campus appoint tomorrow june thank',
#  'my famili idea zero vaccin i i tell these peopl vaccin quiet even kid anti vaccin parent go get vaccin parent know they need colleg',
#  'lol see pictur got happi phase caus wear mask vaccin colleg',
#  'then dont colleg elementari middl high school like vaccin gimm break',
#  'petit no mandatori covid vaccin byu hawaii',
#  'and come univers mandat vaccin put kid risk myocard thing how stop ani doctor will write exempt kid dont want jab like colleg',
#  'you vaccin school you vaccin colleg in sincer im struggl understand vaccin infring freedom wouldnt vaccin aid abil live longer worri free life freedom',
#  'congratul covid vaccin lotteri winner shelli wyramon amp vanya martinez shelli mother amp teacher won million year old vanya won k colleg scholarship',
#  'anti vaxx parent kill kid the allow teenag age covid vaccin parent consent mani enter colleg we need sure vaccin vaccinessavel deltavari',
#  'sir covid vaccin suppli silchar medic colleg centr cachar ran vaccin i resid near smch bt i travel bagha aprxmt kms frm place is fault channel',
#  'the vaccin specif requir the negat covid test what talk besid colleg kid athlet i proof vaccin public high school colleg countri was nazi ish',
#  'the indianaunivers student right refus covid vaccin equal right shlep burger colleg dropout fuckem',
#  'carri origin photocopi follow doc offer letter colleg passport visa if aadhaar card st vaccin certificatei suggest reach centr token secur guard drive start',
#  'hundr member colleg communiti make inform decis covid vaccin follow month share stori rrc employe student alumni get vaccin import',
#  'it fuck make colleg student vaccin i aint vaccin attend nsu',
#  'you attend colleg w o covid vaccin it fda approv',
#  'the polit cultur war vaccin mandat colleg univ gop state disast fall student return low vax rate delta variant domin winter drive peopl indoor',
#  'vaccin lotto winner recent myrtl grove middl school grad vania martinez said win money colleg tuition shock life chang famili',
#  'heartbreak a beauti young soul begin life vaccin children b halt immedi isnt surviv rate peopl my grandkid vaccin return school colleg job stop',
#  'how covid vaccin win scholarship bristol cc clinic',
#  'last year leagu forc colleg player stay shut season turn fals case covid myocard actual case vaccin',
#  'truli ask friend recours employ mandat employe vaccin friend earli s healthi recent colleg grad start field studi onli opt quit vaccin is',
#  'im ok i kid left hes go colleg the got special vaccin correct strain you know flu peopl peopl die justifi ill card busi',
#  'all peopl mad vaccin requir forget requir school colleg travel countri dont fuck dumb',
#  'last summer want colleg footbal cancel myocard covid sound disproven notic silenc vaccin myocard alma mater forc vaccin biggest coward sport',
#  'like incent cash colleg hope young peopl nc vaccinenot chanc scholarship help protect nc and i wish nc expect enter colleg fall',
#  'we happi join white hous covid colleg vaccin challeng know communiti safer healthier fulli vaccin state slcc presid deneec huftalin',
#  'frank karma real bitch am i right elliott opinion if athlet wont vaccin colleg world seri disast go happen',
#  'zero colleg basebal player vaccin serious affect covid year the protocol joke complet inconsist actual logic',
#  'it like peopl badg honor colleg diploma use better vaccin black squar fb page meaningless mfer lift finger help',
#  'you know spike protein common vaccin infect diseas right what laughabl cite articl site clear sourc anti vaccin misinform you clear ace basic colleg biolog',
#  'when excelsior pass avail resid ny receiv vaccin differ state colleg student thank',
#  'so organ sport club high school colleg date shot physic vaccin medic record right this thing dont rememb complain whi peopl care this vaccin',
#  'becaus vaccin fad discredit scientif valor major thing popul follow ppl care bcuz fad if colleg player compens popular care',
#  'discrimin type wrong okay concert peopl colleg degre peopl outrag bc make choic opportun same thing vaccin not make choic so u punish',
#  'meaningless waffl you order staff expos covid infect vaccin hesit cohort countri situat wors colleg and facilit holist colleg experi',
#  'sure forc vaccin colleg student these vax mandat need stop',
#  'you dumb and ignor a new jersey student colleg new jersey institut technolog requir student fulli vaccin order attend class fall ill hour receiv second dose moderna covid vaccin',
#  'wrong it head enter concert work travel plane colleg vaccin that not choic pretti soon wont abl enter groceri store buy food covid jab this tyranni nazi tyranni',
#  'sow colleg amp univers az think mandat vaccin student good thing',
#  'it grt decis telangana govt thank corona vanish long colleg remain close r suffer mnths vaccin attend colleg',
#  'i wait perform live audienc help ensur health amp safeti columbia colleg communiti we encourag student faculti amp staff covid vaccin head fall semest wearecc',
#  'im surprsi colleg provid free vaccin bcus expect worst lol sinovac local student wait allow nonn local student abl',
#  'i rememb panic press said numer colleg pro athlet die covid he team difficulti get covid choic emerg vaccin diseas pose statist threat',
#  'i feel aw colleg student blackmail take vaccin',
#  'go push vaccin colleg kid how g peopl injur kill attent',
#  'want free covid vaccin today here legaci event center site close thursday davi technic colleg kaysvill e s south end campus am pm on spot appoint avail',
#  'they hypocrit the bishop central massachusett anti vaxxer tell colleg student avoid vaccin mandat return fall',
#  'dont vaccin school freedom choic im sure right wing christian colleg wont requir vax',
#  'again your push misinform ive walk here univers maryland colleg medicin break tldr covid vaccin went time rigor test vaccin',
#  'lmao colleg athlet mad facebook colleg requir vaccin bet dollar u send yr vac record year ago team isnt fuckin new oh god',
#  'need help civil right issu mandat vaccin colleg student',
#  'my apart complex colleg mask free vax vaccin effect have cold year best experi life youll damn tri mask',
#  'this evid non mask covid and colleg town safe open vaccin requir',
#  'im sure feel good particular help my colleg educ mom laugh flat earther believ there reason delay get vaccin better understood were go shame peopl like chang mind',
#  'how colleg covid vaccin mandat put student in danger',
#  'did employ requir vaccin job that illeg infring right some colleg requir vaccin rational well someplac dont come colleg',
#  'i watch extrem inform practic matter help i colleg age son va covid threat mandat univers vaccin would',
#  'hallo unrol how colleg covid vaccin mandat put student in danger the',
#  'just colleg student receiv dose vaccin plan open colleg conduct offlin examin see realiti make illog statement cancelvtuexam noexamsuntilvaccin reconsiderreopen karnataka',
#  'you need to get that father to sue the colleg that forc his son gt gt that is the onli way to stop the forc vaccin shit gt gt protect young men gt i have a heart condit gt i am onli gt do not allow this to continu',
#  'colleg say student must get covid vaccin but no not that one',
#  'congrat winner summer cash cash colleg draw you chanc win million post secondari educ it easi enterget vaccin',
#  'consid case yo male dose mrna vax covid pcr covid late he concern friend myocard vaccin want nd dose colleg work mandat second dose',
#  'we get wave local outbreak area lower vaccin rate most adult teen want shot point vaccin requir work colleg also import canada reopen europ mexico uk coupl week',
#  'stat death vaccin advers effect on zoe king colleg app lot peopl report effect nd jab',
#  'all student human studi colleg hep b shot graduat anim care student rabi shot protect it normal add covid vaccin',
#  'registr massvaxmillion open if taken covidma vaccin enter win million colleg scholarship havent vaccin get shot today enter contest',
#  'vaccin center age group mumtaz degre p g colleg saidabad pin vaccin covishield cost free total slot avail jul dose dose cowin',
#  'just got email communiti colleg return work requir fall semest not vaccin provid proof wear mask seem like dont trust vaccin dont trust peopl self report',
#  'this small sweet victori pa thaddeus steven colleg technolog offici rescind mandatori covid vaccin requir',
#  'trump push vaccin children healthi colleg kid virus superior immun the virus undoubt help obes condit trump push choic',
#  'immun respons contagi do peopl get massiv outbreak mening year colleg the meningococc vaccin requir colleg immun respons contagi wed lot mening',
#  'it bound happen yes i daughter wallet vaccin card wash sigh it surviv think shell get new printout colleg record',
#  'two reign pageant queen north carolina visit robeson communiti colleg wednesday help promot covid vaccin clinic accord school',
#  'when physician silenc diagnos jeopardi if patient present likelihood reaction e g vaccin dose booster propos obvious ignor abund caution amp fear colleg repercuss',
#  'massachusett lead higher educ surpris everi state u campus sign white hous covid colleg vaccin challeng let',
#  'colorado kid got covid vaccin iowa colleg both dose moderna you send mail encourag shot list save resourc',
#  'when i colleg downstair neighbor live iron lung she snoopi sticker she polio child polio real i lucki mom big vaccin advoc',
#  'a tall kid won colleg scholarship say didnt know mom enter vaccin lotteri',
#  'colleg forc vaccin',
#  'no way or allow tax reduc zero money invest real enterpris hoard also tax privat colleg endow also moderna vaccin fund govt money',
#  'some someth south korea alleg take advantag govern scheme aim vaccin student head csat suneung exam',
#  'i figur dont need colleg degre smart fall tracker vaccin theori your data track time use gps phone bankcard so smart peopl believ shit antivaxconspiraci',
#  'chang school educ did actual analyz studi or read headlin funni ignor doubl blind control vaccin studi believ observ studi bias one semest colleg wow',
#  'ct public health offer colleg student stipend join effort focus address vaccin hesit help scale hesit covid vaccin',
#  'im tri pictur like mask wear vaccin spread colleg educ scienc liter doctor vote republican rest anti mask anti vaccin anti colleg anti scienc fuck moron',
#  'hey massachusett resid registr vaxmillion start today you chanc win m colleg scholarship fulli vaccin vaccin shot jab',
#  'pleas encourag student fulli vaccin return school colleg univers autumn those requir vaccin dose vaccin earli juli nd dose near middl august the delta variant caus ill school closur',
#  'march read imperi colleg report measur need lower mortal rate covid realiz scale face vaccin potenti end societi knew fact i parent i broken',
#  'if year old son posit covid test symptom confirm antibodi colleg mandat vaccin recommend j amp j concern mrna vax myocardi report young male need decis asap meet entranc requir',
#  'i bus train colleg im elig vaccin im i caught covid year i extrem bad so public transport jab let ill keep mask public transport',
#  'for thing visit vaccin site thank encourag work get vaccin for shes teach class colleg english professor shes involv effort rais fund anim chariti',
#  'favorit bomb iran day kill k job terribl vaccin distribut condon concentr camp china or know pre rehears question hes ask month free colleg due tell i eager know',
#  'grab jab today calderdal colleg no appoint need pm pfizer vaccin second dose week for detail visit',
#  'you impress peopl dont vaccin stay home go mask this case',
#  'graduat student tell rfk jr how she took her school covid vaccin polici won',
#  'didn t accident rubyprincess sydneyloc health district nswhealth said error led entir y cohort st joseph vaccin instead aborigin student nswpol auspol',
#  'a number us colleg led eugen field year ago lead mandatori vaccin they similar lack scientif basi follow popular myth guis scienc they need help',
#  'gbc proud vaccin champion colleg our student faculti staff take pledg wecandothi we safe take covidcollegechalleng pledg commit action get covid vaccin',
#  'gov wolf veto ban pennsylvania government colleg covid vaccin passport nbcphiladelphia',
#  'do year student nsw privileg sydney privat school student given pfizer vaccin despit s inelig',
#  'be chosen in person aug kennedi king colleg this free event open fulli vaccin peopl get vaxx miss regist',
#  'i complet vaccin also book slot friend colleg amp neighbour also teach book slot person book doesnt know book slot also awar peopl understand vaccin safe',
#  'mis manag medic colleg mgm vaccin center year older man stand q hr heav sun summer rain bodi care medic colleg administr silenc',
#  'my friend daughter go freshman colleg preme her mom get fake vaccin card',
#  'someon serious expect believ if danger incompet action vaccin an error health depart say sydney privat school student given pfizer vaccin mistak',
#  'stay safe vaccin el camino colleg host day covid vaccin clinic week juli the event run provid open public free charg appoint amp walk in welcom more info',
#  'if true peopl forc vaccin kid colleg student none risk whi colleg staff concern vaccin protect risk elimin claim',
#  'if pupil colleg vaccin vaccin effect mean person protect constant pupil protect',
#  'the univers utah take covid colleg vaccin challeng and go need help member campus communiti success',
#  'your decis requir student vaccin fall put potenti risk long term health relat issu',
#  'una partner particip covid colleg vaccin challeng for challeng una provid access covid vaccin campus to schedul vaccin click',
#  'the high effici vaccin mass product vaccin china play import role control global covid epidem said zoltn kis expert futur vaccin manufactur research fvmr hub imperi colleg london',
#  'grab covid vaccin richmond town centr saturday just walk appoint nhs number requir locat richmond adult communiti colleg pm saturday th juli both pfizer astrazeneca vaccin avail nd dose wks st',
#  'im urban missourian i got vaccin i want visit state parent amp help stepdaught st colleg dorm west coast the vaccin add extra protect hospit delta variant spread quick mo',
#  'half probabl coke snort way colleg hospit worker wont vaccin ok',
#  'my state vaccin lotteri younger ppl someon won m scholarship colleg i look wapo yesterday accord tracker rate state reach march it unreal',
#  'finish colleg tomorrow celebr w second vaccin',
#  'age elig student colleg student vaccin safe school year offer free vaccin clinic when go',
#  'explain half term spread covid give greater chanc vaccin escap',
#  'dr orient associ american physician surgeon say it outrag young peopl forc vaccin theyll kick colleg dont',
#  'eye offlin class karnataka focus covidvaccin shot colleg student ndtvs maya sharma report read',
#  'uh i went commut colleg all student vaccin record admiss amp vaccin current mid s same true parent went colleg s you millenni will ignor',
#  'he said school child age group main suffer heart damag colleg age and tout amp take credit vaccin',
#  'the fat f cker scienc denier never develop vaccin he couldn t tell beaker bunsen burner cadetbonespur hire proxi colleg entranc exam darwin care unvaccin follow sediti cult parti deathlotteri',
#  'get nd vaccin shot sheridan colleg gymnasium da babi blast speaker tri fear needl peak',
#  'soooo bout vaccin health get cancel you fli colleg if caught mask public anti vaccer jail amp huge fine it time stop pussyfoot asshol',
#  'whi healthi colleg athlet experiment vaccin',
#  'i dont hear colleg kid complain have vaccin you vaccin attend grammar school so shut save life process',
#  'we forc offlin exam situat where peopl took vaccin vulner virus outsid colleg expect offlin exam juli peopl see plzz help reach govt pleas',
#  'we student faculti staff member colleg jccc take pledg commit action get covid vaccin learn',
#  'oh wait convinc pre vaccin patient got sick amp surviv vaccin how conveni guess know whoever run vaccin market racket sure didnt colleg statist mayb amp know exact hide accur result',
#  'for colleg student say vaccin befor th juli i dose vaccin mid stop befor day vaccin till today i dont',
#  'announc cash colleg winner year old vania martinez start summer job save colleg after see suffer lose love one martinez research got vaccin now ride year colleg',
#  'imperi winter exit wave whitti cite delay step afford opportun increas popul level vaccin protect exampl booster dose vaccin children year',
#  'it time vaccin covid vaccin drive the vaccin reduc risk infect the vaccin protect sever ill the vaccin help reconnect friend famili colleg shaheen nagar bidar covidvaccinationdr',
#  'how colleg covid vaccin mandat put student in danger copolit ncaa big big sec',
#  'if play team sport get covid vaccin team doesnt experi',
#  'thank thank post articl this articl known ii wait this problem vaer there known connect vaccin young teen death come colleg prof call pickl death theori',
#  'i kid my yr old came home colleg live w elder parent got vaccin want i minor adult idk parent i surviv wks covid hell thought i go die surviv im wait',
#  'i imagin alarm number freshmen opt colleg avoid take vaccin',
#  'again year old son covid confirm test symptom posit antibodi now colleg requir vaccin as mother doctor advis',
#  'the vaccin brought spread adult age factor vulner most colleg student get order wear mask continu test not sure k',
#  'jude diggin director royal colleg nurs this diseas disappear juli no avail vaccin effect public mask wear straightforward establish govern regret day sent wrong signal polit expedi',
#  'wore mask groceri today im vaccin help feel safer especi guy line ahead told cashier wasnt get stupid vaccin he ask kid went colleg yes said wasnt bshe free',
#  'they chang medic advic ama royal colleg physician it substandard marker type vaccin creation pathway creat j amp j pfizer moderna went rout creat their',
#  'let tri nc colleg student incent prior student or parent student m k vax bonu nc colleg w highest vax rate ncgov nc doctor incentiv counsel medicaid patient covid vax',
#  'a friend famili son got vaccin colleg requir he got complain bodi ach inject site pain immedi follow the morn father dead bed blood pour orific no thank scott',
#  'no i doubt mani wait vaccin fulli approv add vaccin requir colleg like measl mump rubella the rest probabl protect',
#  'yall know school requir certain vaccin order student attend right isnt new concept new vaccin that requir wouldnt feel safe colleg campus know peopl transmit dead virus',
#  'new appoint avail loyalist colleg',
#  'chicago parti in person saturday august th kennedi king colleg this free event open fulli vaccin guest resid of chicago to attend vaxx amp regist',
#  'you hate modi amp bjp protest put banner it ok dont want thank free vaccin fine choic you state colleg kerala saudabad place karachi thankless vaccin it demean countri',
#  'sir month th june nd dose vaccin date medic colleg mgm dimna vaccin avail th inform regular enquiri',
#  'my daughter colleg athlet theyr push vaccin mandatori bunch covid fall girl got covid vax month ago test posit yesterday my daughter test time school covid vax lot w covid',
#  'we marwari yuwa manch manag vaccin centr mariani colleg organis mariani municip street vendor they unawar process first regist cowin provid vaccin provid free certif',
#  'parent pressur play need colleg not generat gap i rememb vietnam tore famili apart schism fuel ignor',
#  'then dont colleg elementari middl high school like vaccin gimm break',
#  'year old colleg freshman die from heart problem one month after second dose moderna vaccin children health defens how sad',
#  'im feel effect vaccin lot school req finish colleg hell sana binaril niyo nalang ak lt',
#  'my youngest grandson rd year colleg requir vaccin return class i hope school when children school i vaccin year',
#  'ive got vaccin i extrem concern suppress activ discuss safeti vaccin disciplin doctor speak vaccin public health colleg surgeon someth isnt right',
#  'no listen besid forc vaccin grade school colleg i attend i didnt proof vaccin i need adult vaccin work food servic industri i proof',
#  'your vaccin mandat point lack consider sport program protect season major disrupt big ten rule probabl stringent look happen colleg basebal team the school respons',
#  'pls sem wanna colleg vaccin i wanna get shot too',
#  'congratul covid vaccin lotteri winner shelli wyramon amp vanya martinez shelli mother amp teacher won million year old vanya won k colleg scholarship',
#  'i hold parent respons govern mom say shes pro scienc look scienc daughter gotten vaccin their colleg degre profess close minded arrog caus',
#  'nc state basebal numer vaccin player test posit covid forc forfeit colleg work seri semi final best vaccin effect',
#  'to unawar option go far aid ban usag countri but ofc abt money so i trust amp forc vaccin order abl colleg option immun',
#  'thank pass amend protect k colleg student mandat vaccin fda approv keep fight freedom',
#  'the data imperi colleg london suggest technolog generat immun respons covid peopl extrem low dose level lowest covid vaccin candid worldwid',
#  'forc colleg student receiv covid vaccin order educ unconstitut shame univers mandat requir vaccin it bodi their choic prochoic remindyouofsometh nomandatoryvaccin',
#  'the funni suppos vaccin second dose kal ig theyv delay week plus follow sop colleg lolol parha kuch hai nahi na dimagh chal raha hai plus uni admiss open idk kid deal tbh',
#  'it funni pathet colleg like vaccin come colleg faildur a global pandem']

# %%
#creating frequency matrix
vectorizer = CountVectorizer(min_df=2)

# %%
#fitting random forest classifier, using all data as training set right now
clf = RandomForestClassifier()

# %%
#kfold random forest validation
def kfold_forest_validation(features, labels, k = 4, shuf = False):
    k_fold = KFold(n_splits = k, shuffle=shuf)
    rfc_list = []
    
    for k, (train, test) in enumerate(k_fold.split(features)):
        clf.fit(features[train], labels[train]) #fitting training data
        label_pred = clf.predict(features[test]) #using trained data to fit to using only X features from test dataset
        rfc_val = (label_pred==labels[test]).sum() / test.size #proportion of correctly predicted points
        rfc_list.append(rfc_val)
    
    return np.mean(rfc_list)

# %%
#only tokens (words), no sentiment
features = vectorizer.fit_transform(process_tweets).toarray() #document term matrix w/ frequencies, our "features", the words
manlabels = np.array(tweet_label["vader_match"]) #our manual labels

#only tokens, no sentiment
kfold_forest_validation(features, manlabels)
# Out:
# 0.6676136363636364

# %%
#including vader sentiment label as a feature
#creating matrix of features
reshaped_values = np.reshape(tweet_label["assigned"].to_numpy(), (len(tweet_label["assigned"]), 1)) #vader sentiment decisions
features_with_sentiment = np.append(features, reshaped_values, 1)

#validation
kfold_forest_validation(features_with_sentiment, manlabels)
# Out:
# 0.7258522727272727

# %%
#including vader sentiment labels AND values

#creating matrix of features
#first including positive sentiment
reshaped_vader_positive = np.reshape(tweet_label["positive"].to_numpy(), (len(tweet_label["positive"]), 1)) #vader positive sentiment
features_with_sentiment_vals = np.append(features_with_sentiment, reshaped_vader_positive, 1)

#and negative sentiment
reshaped_vader_negative = np.reshape(tweet_label["negative"].to_numpy(), (len(tweet_label["negative"]), 1)) #vader positive sentiment
features_with_sentiment_vals = np.append(features_with_sentiment_vals, reshaped_vader_negative, 1)

#validation
kfold_forest_validation(features_with_sentiment_vals, manlabels)
# Out:
# 0.7556818181818181

# %%
#k nearest neighbor test with only sentiment values

vader_positive = np.reshape(tweet_label["positive"].to_numpy(), (len(tweet_label["positive"]), 1)) #vader positive sentiment
vader_negative = np.reshape(tweet_label["negative"].to_numpy(), (len(tweet_label["negative"]), 1)) #vader positive sentiment
vader_sentiments = np.append(vader_positive, vader_negative, 1)


knn = neighbors.KNeighborsClassifier(n_neighbors = 5) #arbitarily chose 5
k_fold = KFold(n_splits = 4, shuffle=False)

knn_list = []

for k, (train, test) in enumerate(k_fold.split(vader_sentiments)):
    #k-nearest neighbors
    knn.fit(vader_sentiments[train], manlabels[train]) #fitting NN with X features and y classes
    knn_pred = knn.predict(vader_sentiments[test]) #using trained data to fit to using only X features from test dataset
    knn_val = (knn_pred==manlabels[test]).sum() / test.size #proportion of correctly predicted labels
    knn_list.append(knn_val)

np.mean(knn_list)
# Out:
# 0.6732954545454546

# %%
#random forest with just the sentiment values
clf.fit(features_with_sentiment_vals, manlabels)
rfc_list = []

for k, (train, test) in enumerate(k_fold.split(vader_sentiments)):
    clf.fit(vader_sentiments[train], manlabels[train]) #fitting training data
    label_pred = clf.predict(vader_sentiments[test]) #using trained data to fit to using only X features from test dataset
    rfc_val = (label_pred==manlabels[test]).sum() / test.size #proportion of correctly predicted points
    rfc_list.append(rfc_val)
    
np.mean(rfc_list)
# Out:
# 0.6661931818181818
